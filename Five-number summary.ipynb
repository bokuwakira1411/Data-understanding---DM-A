# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path_FinancialIdicatior = "/kaggle/input/b-and-d-understanding/Simplize_FPT_FinancialIndicator_20250315.xlsx"
file_path_PriceHistory = "/kaggle/input/b-and-d-understanding/Simplize_FPT_PriceHistory_20250315.xlsx"

# %%
# Đọc dữ liệu (Read data)
data_FinancialIdicatior = pd.read_excel(file_path_FinancialIdicatior)
data_PriceHistory = pd.read_excel(file_path_PriceHistory)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Xóa những cột không liên quan (Remove irrelevant columns)
threshold = data_FinancialIdicatior.shape[1]*0.7
data_FinancialIdicatior_cleaned = data_FinancialIdicatior.dropna(thresh = threshold)
data_PriceHistory_cleaned = data_PriceHistory.iloc[4:1005]
data_FinancialIdicatior_cleaned = data_FinancialIdicatior_cleaned.reset_index(drop = True)
data_PriceHistory_cleaned = data_PriceHistory_cleaned.reset_index(drop = True)

# %%
data_FinancialIdicatior_cleaned
# Out:
#                                            Unnamed: 0       Unnamed: 1  \
# 0                                            CHỈ TIÊU          Q4/2024
# 1                                     Doanh thu thuần   17607817805892
# 2                               Tăng trưởng doanh thu           0.1986
# 3                                       Lợi nhuận gộp    6478973351926
# 4                           Tăng trưởng lợi nhuận gộp           0.1504
# 5                             Lợi nhuận thuần từ HĐKD    2922046994779
# 6                         Tăng trưởng lợi nhuận thuần           0.2243
# 7                                Lợi nhuận trước thuế    2959667491092
# 8                    Tăng trưởng lợi nhuận trước thuế           0.2154
# 9           Lợi nhuận sau thuế của Cổ đông công ty mẹ    2086993221115
# 10                     Tăng trưởng lợi nhuận sau thuế           0.2075
# 11                                       Tổng tài sản   72013238235529
# 12                           Tăng trưởng Tổng tài sản           0.1937
# 13                                   Tài sản ngắn hạn   45475495956466
# 14                       Tăng trưởng tài sản ngắn hạn           0.2388
# 15                                    Tài sản dài hạn   26537742279063
# 16                        Tăng trưởng tài sản dài hạn           0.1237
# 17                                        Nợ ngắn hạn   34780312270522
# 18                            Tăng trưởng nợ ngắn hạn           0.1723
# 19                  Vay và nợ thuê tài chính ngắn hạn   14446238451323
# 20              Tăng trưởng vay và nợ thuê tài chí...            0.044
# 21                                         Nợ dài hạn    1436299546037
# 22                             Tăng trưởng Nợ dài hạn            1.024
# 23                                     Vốn chủ sở hữu   35796626418970
# 24                         Tăng trưởng vốn chủ sở hữu           0.1953
# 25                                    Vốn góp cổ phần   14710691830000
# 26                        Tăng trưởng vốn góp cổ phần           0.1584
# 27                                                P/E        26.886181
# 28                                                P/B         6.782432
# 29                                          EV/EBITDA              NaN
# 30                                       EPS (VNĐ/CP)      1418.691415
# 31                                    Tăng trưởng EPS           0.0424
# 32                           Giá trị sổ sách (VNĐ/CP)     20300.156504
# 33                                 Biên lợi nhuận gộp            0.368
# 34                                          Biên EBIT           0.1757
# 35                                        Biên EBITDA           0.2137
# 36                                Biên lợi nhuận ròng           0.1416
# 37                                            ROE LTM           0.2866
# 38                                            ROA LTM           0.1424
# 39                           Vòng quay tài sản (vòng)          0.25227
# 40                  Hiệu suất sử dụng tài sản cố định         0.635869
# 54       459344308       459344308       399436093       397449264
#
#        Unnamed: 39     Unnamed: 40
# 0          Q2/2015         Q1/2015
# 1    9328539915897   8641481450290
# 2           -0.127         -0.2048
# 3    1801912782980   1689717875940
# 4           0.1595          0.2562
# 5     711603570023    628940977842
# 6           0.1324          0.1095
# 7     705024545629    645332005032
# 8           0.0931          0.1096
# 9     456633177453    424660831199
# 10          0.0679          0.1747
# 11  22581606338389  22206060192447
# 12           0.271          0.2728
# 13  16240764508172  16319850549250
# 14          0.2758          0.2882
# 15   6340841830217   5886209643197
# 16          0.2588           0.232
# 17  12339405503283  11843484471978
# 18          0.4347          0.4078
# 19   6203353547591   6745213941326
# 20          0.6108          0.5372
# 21    317988405822    519083313646
# 22          0.1178          0.7463
# 23   9924212429284   8380860246563
# 24          0.3079          0.1065
# 25   3975316400000   3439766000000
# 26          0.1557          0.2499
# 27        10.40681       10.219301
# 28        2.100859        2.104235
# 29         5.88707        5.493141
# 30     1148.909355     1068.465512
# 31          -0.076          0.0164
# 32    21346.303503    21086.616597
# 33          0.1932          0.1955
# 34          0.0826          0.0794
# 35          0.1022          0.0982
# 36          0.0633          0.0633
# 37          0.2484          0.2685
# 38          0.1078           0.108
# 39        0.416567        0.385215
# 40        1.439742        1.431082
# 41      169.772286      183.644984
# 42      233.930949      247.037716
# 43      167.418022      171.018986
# 44      236.285213      259.663714
# 45          1.2754          1.4751
# 46          0.6389          0.8253
# 47          0.2122          0.2413
# 48        2.304017         2.48528
# 49        1.784064        1.796234
# 50        0.926343        0.969509
# 51        0.343211        0.413302
# 52       14.527993       20.776078
# 53  20468637096000  18799350187200
# 54       397449264       397449264
#
# [55 rows x 41 columns]

# %%
all_data = []
for i in range(1, 55):  
    row = data_FinancialIdicatior_cleaned.iloc[i, 1:]  # Lấy dữ liệu số từ cột 2 trở đi
    # Tính Five-Number Summary
    five_number_summary = row.quantile([0, 0.25, 0.5, 0.75, 1])
    
    # Gộp kết quả
    all_data.append({
        "Name" : data_PriceHistory_cleaned.iloc[i, 0],
        "Min": f"{float(five_number_summary[0.00]):.2f}",  
        "Q1" : f"{float(five_number_summary[0.25]):.2f}",
        "Median" : f"{float(five_number_summary[0.50]):.2f}",
        "Q3" : f"{float(five_number_summary[0.75]):.2f}",
        "Max" : f"{float(five_number_summary[1.00]):.2f}"
    })
df = pd.DataFrame(all_data, columns=["Name", "Min", "Q1", "Median", "Q3", "Max"])
df.to_excel("five_number_summary_FinancialIdicatior.xlsx", index=False)

# %%
all_data = []
for i in range(1, 8):  
    row = data_PriceHistory_cleaned.iloc[1:, i]  # Lấy dữ liệu số từ đòng 2 trở đi
    # Tính Five-Number Summary
    five_number_summary = row.quantile([0, 0.25, 0.5, 0.75, 1])
    #Gộp kết quả
    all_data.append({
        "Name" : data_PriceHistory_cleaned.iloc[0, i],
        "Min": f"{float(five_number_summary[0.00]):.2f}",  
        "Q1" : f"{float(five_number_summary[0.25]):.2f}",
        "Median" : f"{float(five_number_summary[0.50]):.2f}",
        "Q3" : f"{float(five_number_summary[0.75]):.2f}",
        "Max" : f"{float(five_number_summary[1.00]):.2f}"
})
df = pd.DataFrame(all_data, columns=["Name", "Min", "Q1", "Median", "Q3", "Max"])
df.to_excel("five_number_summary_PriceHistory.xlsx", index=False)

# %%
# Lấy dòng 1 (chỉ số 1) làm tên cột
data_PriceHistory_cleaned.columns = data_PriceHistory_cleaned.iloc[0]
data_FinancialIdicatior_cleaned.columns = data_FinancialIdicatior_cleaned.iloc[0]

# Xóa dòng 1 vì nó đã được dùng làm tên cột
data_PriceHistory_cleaned = data_PriceHistory_cleaned.drop(0).reset_index(drop=True)
data_FinancialIdicatior_cleaned = data_FinancialIdicatior_cleaned.drop(0).reset_index(drop=True)

# %%
data_PriceHistory_cleaned
# Out:
# 0          NGÀY    GIÁ MỞ CỬA  GIÁ CAO NHẤT GIÁ THẤP NHẤT  GIÁ ĐÓNG CỬA  \
# 0    14/03/2025        135600        136300        130800        131400
# 1    13/03/2025        136100        138000        136100        136500
# 2    12/03/2025        137700        138700        135900        135900
# 3    11/03/2025        138000        138500        137000        137500
# 4    10/03/2025        141500        141500        139200        139300
# ..          ...           ...           ...           ...           ...
# 995  19/03/2021  40523.598023   40776.87051  40219.671037  40422.289028
# 996  18/03/2021  41030.142998  41030.142998  40523.598023  41030.142998
# 997  17/03/2021  41283.415486  41283.415486  40523.598023  40928.834003
# 998  16/03/2021  39003.963097  41283.415486  38801.345107  41030.142998
# 999  15/03/2021  38801.345107  39257.235584  38548.072619  38750.690609
#
# 0   THAY ĐỔI GIÁ % THAY ĐỔI KHỐI LƯỢNG
# 0          -5100  -0.037363   16094000
# 1            600   0.004415    3610200
# 2          -1600  -0.011636    6185000
# 3          -1800  -0.012922    5784400
# 4          -2100  -0.014851    5323000
# ..           ...        ...        ...
# 995          NaN        NaN    2923500
# 996          NaN        NaN    2177500
# 997          NaN        NaN    2573500
# 998          NaN        NaN    5171000
# 999          NaN        NaN    1801400
#
# [1000 rows x 8 columns]

# %%
data_PriceHistory_cleaned['NGÀY']= pd.to_datetime(data_PriceHistory_cleaned['NGÀY'], dayfirst=True)
df = data_PriceHistory_cleaned[['NGÀY','GIÁ ĐÓNG CỬA']]

# %%
plt.hist(df['GIÁ ĐÓNG CỬA'], bins = 10, edgecolor='black')
plt.title('Biểu đồ Histogram')
plt.xlabel('Giá đóng cửa')
plt.ylabel('Tần suất')
# Out:
# Text(0, 0.5, 'Tần suất')

# %% [markdown]
# Nhận xét: Vì biểu đồ histogram có đuôi kéo dài về bên phải nên dữ liệu lệch phải. Dữ liệu tập trung nhiều nhất trong khoảng 50000 đến 60000, với tần suất lớn hơn 400.

# %%
plt.boxplot(df['GIÁ ĐÓNG CỬA'])
plt.title('Biểu đồ Box Plot')
plt.ylabel('Giá đóng cửa')
# Out:
# Text(0, 0.5, 'Giá đóng cửa')

# %% [markdown]
# Nhận xét:
# - Giá trị nhỏ nhất của dữ liệu khoảng 40000, giá trị trung vị khoảng 60000, trong khi đó giá trị lớn nhất bằng 155000, cho thấy rằng phạm vi biến động của giá trị cổ phiếu khá lớn.
# - Không có giá trị ngoại lai trên biểu đồ.
